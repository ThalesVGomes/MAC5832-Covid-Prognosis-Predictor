# %% [markdown]
# # Notebook gerar e testar Dataset v2

# %% [markdown]
# ---

# %% [markdown]
# ### 1) Setup

# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import balanced_accuracy_score, make_scorer, f1_score, recall_score,precision_score
from sklearn.model_selection import RepeatedKFold, cross_val_score, GridSearchCV, cross_validate

import optuna
import lightgbm as lgb

from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

from sklearn.ensemble import RandomForestClassifier
from boruta import BorutaPy

from sklearn.model_selection import train_test_split

# %%
SEED = 42

ARTIGO_TRAIN_CLINICAL_FILENAME = "datasets/artigo/train_set_clinical.csv"
ARTIGO_TEST_CLINICAL_FILENAME = "datasets/artigo/test_set_clinical.csv"

ARTIGOV2_TRAIN_CLINICAL_FILENAME = "datasets/artigo_v2/train_set_clinical.csv"
ARTIGOV2_TEST_CLINICAL_FILENAME = "datasets/artigo_v2/test_set_clinical.csv"

NORMALIZADO_TRAIN_CLINICAL_FILENAME = "datasets/normalizado/train_set_clinical.csv"
NORMALIZADO_TEST_CLINICAL_FILENAME = "datasets/normalizado/test_set_clinical.csv"

NORMALIZADOV2_TRAIN_CLINICAL_FILENAME = "datasets/normalizado_v2/train_set_clinical.csv"
NORMALIZADOV2_TEST_CLINICAL_FILENAME = "datasets/normalizado_v2/test_set_clinical.csv"

# %% [markdown]
# ---

# %% [markdown]
# ### 2) Read and Preprocess Data

# %%
datasets = {
    'normalizado': {
        'train': pd.read_csv(NORMALIZADO_TRAIN_CLINICAL_FILENAME, sep=";", index_col="ID"),
        'test': pd.read_csv(NORMALIZADO_TEST_CLINICAL_FILENAME, sep=";", index_col="ID")
    },
    'normalizado_v2': {
        'train': pd.read_csv(NORMALIZADOV2_TRAIN_CLINICAL_FILENAME, sep=";", index_col="ID"),
        'test': pd.read_csv(NORMALIZADOV2_TEST_CLINICAL_FILENAME, sep=";", index_col="ID")
    },    
    'artigo': {
        'train': pd.read_csv(ARTIGO_TRAIN_CLINICAL_FILENAME, sep=";", index_col="ID"),
        'test':  pd.read_csv(ARTIGO_TEST_CLINICAL_FILENAME, sep=";", index_col="ID")
    },
    'artigo_v2': {
        'train': pd.read_csv(ARTIGOV2_TRAIN_CLINICAL_FILENAME, sep=";", index_col="ID"),
        'test':  pd.read_csv(ARTIGOV2_TEST_CLINICAL_FILENAME, sep=";", index_col="ID")
    }
}

# %% [markdown]
# ### 2.1) Reparticiona e datasets de forma balanceada
#
#
# Estavámos percebendo o que o aumento no score de validação (~.80) não estava levando aumento similar no score de test (~.58). Talvez a razão seja porque o conjunto de amostra de testes atual foi colhido em momento posterior ao conjunto de treinamento.
#
# A ideia desse repartcionamento é diluir um possível data drift no conjunto de teste e treinamento.
#
# O código abaixo só foi rodado uma vez.

# %%
# normalizado_all = pd.concat([ datasets['normalizado']['train'], datasets['normalizado']['test']], axis=0)
# artigo_all = pd.concat([ datasets['artigo']['train'], datasets['artigo']['test']], axis=0)


# X_train, X_test, Y_train, Y_test = train_test_split(normalizado_all.iloc[:,:-1], normalizado_all.iloc[:,-1],
#                                                     stratify=normalizado_all.iloc[:,-1], 
#                                                     test_size=0.323, random_state=0)

# datasets['normalizado_v2'] = {
#     'train': pd.concat([X_train, Y_train], axis=1),
#     'test': pd.concat([X_test, Y_test], axis=1)
# }

# X_train, X_test, Y_train, Y_test = train_test_split(artigo_all.iloc[:,:-1], artigo_all.iloc[:,-1],
#                                                     stratify=artigo_all.iloc[:,-1], 
#                                                     test_size=0.323, random_state=0)

# datasets['artigo_v2'] = {
#     'train': pd.concat([X_train, Y_train], axis=1),
#     'test': pd.concat([X_test, Y_test], axis=1)
# }


# datasets['normalizado_v2']['train'].to_csv(NORMALIZADOV2_TRAIN_CLINICAL_FILENAME, sep=';', line_terminator='\n')
# datasets['normalizado_v2']['test'].to_csv(NORMALIZADOV2_TEST_CLINICAL_FILENAME, sep=';', line_terminator='\n')
# datasets['artigo_v2']['train'].to_csv(ARTIGOV2_TRAIN_CLINICAL_FILENAME, sep=';', line_terminator='\n')
# datasets['artigo_v2']['test'].to_csv(ARTIGOV2_TEST_CLINICAL_FILENAME, sep=';', line_terminator='\n')

# %%
# Target categories are balanced?
for dataset in datasets.keys():
    df_train = datasets[dataset]['train']
    df_test  = datasets[dataset]['test']
    nr_train_mild = (df_train['Group'] == 'MILD').sum()
    nr_train_severe =(df_train['Group'] == 'SEVERE').sum()
    nr_test_mild = (df_test['Group'] == 'MILD').sum()
    nr_test_severe =(df_test['Group'] == 'SEVERE').sum()
    print(f'Dataset {dataset}')
    print(f'Training MILD: {nr_train_mild} ({nr_train_mild/(nr_train_mild+nr_train_severe):.2}), SEVERE: {nr_train_severe} ({nr_train_severe/(nr_train_mild+nr_train_severe):.2}) = {nr_train_mild+nr_train_severe}')
    print(f'    Test MILD: {nr_test_mild} ({nr_test_mild/(nr_test_mild+nr_test_severe):.2}), SEVERE: {nr_test_severe} ({nr_test_severe/(nr_test_severe+nr_test_mild):.2}) = {nr_test_mild+nr_test_severe} ')
    print()
# Out:
# Dataset normalizado
# Training MILD: 81 (0.61), SEVERE: 51 (0.39) = 132
#     Test MILD: 42 (0.66), SEVERE: 22 (0.34) = 64
#
# Dataset normalizado_v2
# Training MILD: 83 (0.63), SEVERE: 49 (0.37) = 132
#     Test MILD: 40 (0.62), SEVERE: 24 (0.38) = 64
#
# Dataset artigo
# Training MILD: 81 (0.61), SEVERE: 51 (0.39) = 132
#     Test MILD: 42 (0.66), SEVERE: 22 (0.34) = 64
#
# Dataset artigo_v2
# Training MILD: 83 (0.63), SEVERE: 49 (0.37) = 132
#     Test MILD: 40 (0.62), SEVERE: 24 (0.38) = 64

# %%
##### Preprocessing all datasets
for d_key in datasets.keys():
    for d_type in datasets[d_key].keys():
        
        # Drop NaN Values 
        datasets[d_key][d_type].dropna(inplace=True)
        
        # Convert Sex column to boolean (Female: 1, Male: 0)
        datasets[d_key][d_type]["Sex"] = np.where(datasets[d_key][d_type]["Sex"]=="F", 1, 0)

# %% [markdown]
# ---

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import balanced_accuracy_score

def evaluate_test(groundtruth, predicted, print_result=True):
    bal_accuracy = balanced_accuracy_score(groundtruth, predicted)
    accuracy = accuracy_score(groundtruth, predicted)
    tn, fp, fn, tp = confusion_matrix(groundtruth, predicted).ravel()
    specificity = tn / (tn+fp)
    sensitivity  = tp / (tp+fn)
    if(print_result):
        print(f"\n [test:]")
        print(f'Balanced accuracy: {bal_accuracy:.4f}') 
        print(f'Accuracy: {accuracy:.4f}') 
        print(f'Specificity:  {specificity:.4f}')
        print(f'Sensitivity:  {sensitivity:.4f}')
    return (accuracy, specificity, sensitivity)

# Get Features and Target
def getFeaturesTargets(dataset_name):
    dataset = datasets[dataset_name]
    X, y = dataset['train'].drop("Group", axis=1), dataset['train']["Group"]
    X_test, y_test = dataset['test'].drop("Group", axis=1), dataset['test']["Group"]
    return (X, y, X_test, y_test)

# Defining RepeatedKFold Cross Validator
rkf = RepeatedKFold(n_splits=5, n_repeats=10, random_state=SEED)

# Define metric scorer
metric_scorer = make_scorer(balanced_accuracy_score)

# %% [markdown]
# ### 3) Baseline Model Training and CV

# %%
# Select a dataset
def baseline(dataset_name):
    # Define Classifier (or pipeline)
    clf = lgb.LGBMClassifier(random_state=SEED)

    # Get Features and Target
    X, y, X_test, y_test = getFeaturesTargets(dataset_name)

    # No parameters to search now
    parameters = {}

    # Using GridSearchCV instead cross_val_score and cross_validate, because with GridSearchCV we could also evalute a test set
    search = GridSearchCV(clf, parameters, n_jobs=-1, verbose=4, scoring=metric_scorer, cv=rkf, return_train_score=True)
    search.fit(X, y)

    print(f"\n\nDataset: {dataset_name}")
    print(f"Balanced accuracy mean_train: {search.cv_results_['mean_train_score'][0]}, mean_val: {search.cv_results_['mean_test_score'][0]} ")

    predicted = search.best_estimator_.predict(X_test)
    test_score = evaluate_test(y_test, predicted)


for dataset in datasets.keys():
    baseline(dataset)
# Out:
# Fitting 50 folds for each of 1 candidates, totalling 50 fits
#
#
# Dataset: normalizado
# Balanced accuracy mean_train: 1.0, mean_val: 0.7703995514289632
#
#  [test:]
# Balanced accuracy: 0.4578
# Accuracy: 0.5156
# Specificity:  0.6429
# Sensitivity:  0.2727
# Fitting 50 folds for each of 1 candidates, totalling 50 fits
#
#
# Dataset: normalizado_v2
# Balanced accuracy mean_train: 1.0, mean_val: 0.6109552646356052
#
#  [test:]
# Balanced accuracy: 0.6875
# Accuracy: 0.7344
# Specificity:  0.8750
# Sensitivity:  0.5000
# Fitting 50 folds for each of 1 candidates, totalling 50 fits
#
#
# Dataset: artigo
# Balanced accuracy mean_train: 1.0, mean_val: 0.778942822657219
#
#  [test:]
# Balanced accuracy: 0.5390
# Accuracy: 0.5938
# Specificity:  0.7143
# Sensitivity:  0.3636
# Fitting 50 folds for each of 1 candidates, totalling 50 fits
#
#
# Dataset: artigo_v2
# Balanced accuracy mean_train: 1.0, mean_val: 0.6979568114633905
#
#  [test:]
# Balanced accuracy: 0.7333
# Accuracy: 0.7812
# Specificity:  0.9250
# Sensitivity:  0.5417

# %% [markdown]
# ### Resultados
#
# | metrics                     	| normalizado 	| normalizado_v2 	| artigo 	| artigo_v2 	|
# |-----------------------------	|-------------	|----------------	|--------	|-----------	|
# | mean_train*            	| 100%     	| 100%   	| 100%   	| 100%      	|
# | mean_val*              	| 77.03%   	| 61.09% 	| 77.89% 	| 69.79%    	|
# | test balanced_accuracy 	| 45.78%   	| 68.75% 	| 53.90% 	| 73.33%    	|
# | test accuracy          	| 51.56%   	| 73.44% 	| 59.38% 	| 78.12%    	|
# | test specifity         	| 64.29%   	| 87.50% 	| 71.43% 	| 92.50%    	|
# | test sensitivity       	| 27.27%   	| 50.00% 	| 36.36% 	| 54.17%    	|
#
# \* = balanced_accuracy
#
#
# Alguns pontos
# - Todos os modelos parecem estar no regime de overfiting.
# - O score de validação piora nos datasets v2, reparticionados. Talvez a validação tenha ficado mais difícil.
# - As métricas de test melhoram no datasets v2.

# %% [markdown]
# ---

# %% [markdown]
# ##### 4.4) Boruta Feature Selection + Features Scaler + Hyper Parameter Optimization with Optuna
#
# ```
# normalizado_v2
# ````

# %%
# Select a dataset
dataset_name = 'normalizado_v2'

# Get Features and Target
X, y, X_test, y_test = getFeaturesTargets(dataset_name)

# define random forest classifier, with utilising all cores and
# sampling in proportion to y labels
rf = RandomForestClassifier(n_jobs=-1, class_weight='balanced', max_depth=5)
# define Boruta feature selection method
feat_selector = BorutaPy(rf, n_estimators='auto', verbose=2, random_state=SEED, )

feat_selector.fit(np.array(X), y)

print("Number of selected features: ", feat_selector.n_features_)

print(X.columns[feat_selector.support_])

# Filter most importante features
X_transform = feat_selector.transform(np.array(X))
X_test_transform = feat_selector.transform(np.array(X_test))

# Define objectiva funtion to maximize metric
def objective(trial):
    
    # List scalers to chose from
    scalers = trial.suggest_categorical("scalers", ['minmax', 'standard', 'robust'])
    # Define scalers
    if scalers == "minmax":
        scaler = MinMaxScaler()
    elif scalers == "standard":
        scaler = StandardScaler()
    else:
        scaler = RobustScaler()
    # LGBM Hyper Parameter Grid
    param = {
        "objective": "binary",
        "metric": "binary_logloss",
        "verbosity": -1,
        "boosting_type": "gbdt",
        "lambda_l1": trial.suggest_float("lambda_l1", 1e-8, 10.0, log=True),
        "lambda_l2": trial.suggest_float("lambda_l2", 1e-8, 10.0, log=True),
        "num_leaves": trial.suggest_int("num_leaves", 2, 256),
        "feature_fraction": trial.suggest_float("feature_fraction", 0.4, 1.0),
        "bagging_fraction": trial.suggest_float("bagging_fraction", 0.4, 1.0),
        "bagging_freq": trial.suggest_int("bagging_freq", 1, 7),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
        "n_estimators": trial.suggest_int("max_depth", 100, 1000)
    }
    # Create model pipeline with param trial
    clf = Pipeline([("scaler", scaler),
                    ("lgbm_clf", lgb.LGBMClassifier(random_state=SEED, **param))])
    # Get CV Metric we want to maximize
    balanced_accuracy = np.mean(cross_val_score(clf, X_transform, y, scoring=metric_scorer, cv=rkf, n_jobs=-1))
    
    return balanced_accuracy


# Define a detailed objective function to get more metrics of best trial
def detailed_objective(trial):
    
    # List scalers to chose from
    scalers = trial.suggest_categorical("scalers", ['minmax', 'standard', 'robust'])
    # Define scalers
    if scalers == "minmax":
        scaler = MinMaxScaler()
    elif scalers == "standard":
        scaler = StandardScaler()
    else:
        scaler = RobustScaler()
    # LGBM Hyper Parameter Grid
    param = {
        "objective": "binary",
        "metric": "binary_logloss",
        "verbosity": -1,
        "boosting_type": "gbdt",
        "lambda_l1": trial.suggest_float("lambda_l1", 1e-8, 10.0, log=True),
        "lambda_l2": trial.suggest_float("lambda_l2", 1e-8, 10.0, log=True),
        "num_leaves": trial.suggest_int("num_leaves", 2, 256),
        "feature_fraction": trial.suggest_float("feature_fraction", 0.4, 1.0),
        "bagging_fraction": trial.suggest_float("bagging_fraction", 0.4, 1.0),
        "bagging_freq": trial.suggest_int("bagging_freq", 1, 7),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
        "n_estimators": trial.suggest_int("max_depth", 100, 1000)
    }
    # Create model pipeline with param trial
    clf = Pipeline([("scaler", scaler),
                    ("lgbm_clf", lgb.LGBMClassifier(random_state=SEED, **param))])

    # Print params for best trial
    print(f"    scaler: {scaler}")
    for key, value in param.items():
        print("    {}: {}".format(key, value))


    clf.fit(X_transform, y)

    # calculate more evaluation metrics
    predicted = clf.predict(X_test_transform)

    bal_accuracy = balanced_accuracy_score(y_test, predicted)
    accuracy = accuracy_score(y_test, predicted)
    tn, fp, fn, tp = confusion_matrix(y_test, predicted).ravel()
    specificity = tn / (tn+fp)
    sensitivity  = tp / (tp+fn)

    print('[TEST]')
    print(f'balanced_accuracy: {bal_accuracy:.4f}, accuracy: {accuracy:.4f}, specificity: {specificity:.4f}, sensitivity: {sensitivity:.4f}')
    return (bal_accuracy, accuracy, specificity, sensitivity)
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	649
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	649
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	649
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	649
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	649
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	649
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	649
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	0
# Tentative: 	29
# Rejected: 	620
# Iteration: 	9 / 100
# Confirmed: 	0
# Tentative: 	29
# Rejected: 	620
# Iteration: 	10 / 100
# Confirmed: 	0
# Tentative: 	29
# Rejected: 	620
# Iteration: 	11 / 100
# Confirmed: 	0
# Tentative: 	29
# Rejected: 	620
# Iteration: 	12 / 100
# Confirmed: 	0
# Tentative: 	29
# Rejected: 	620
# Iteration: 	13 / 100
# Confirmed: 	0
# Tentative: 	29
# Rejected: 	620
# Iteration: 	14 / 100
# Confirmed: 	0
# Tentative: 	29
# Rejected: 	620
# Iteration: 	15 / 100
# Confirmed: 	0
# Tentative: 	29
# Rejected: 	620
# Iteration: 	16 / 100
# Confirmed: 	0
# Tentative: 	29
# Rejected: 	620
# Iteration: 	17 / 100
# Confirmed: 	0
# Tentative: 	29
# Rejected: 	620
# Iteration: 	18 / 100
# Confirmed: 	0
# Tentative: 	29
# Rejected: 	620
# Iteration: 	19 / 100
# Confirmed: 	3
# Tentative: 	26
# Rejected: 	620
# Iteration: 	20 / 100
# Confirmed: 	3
# Tentative: 	26
# Rejected: 	620
# Iteration: 	21 / 100
# Confirmed: 	3
# Tentative: 	26
# Rejected: 	620
# Iteration: 	22 / 100
# Confirmed: 	5
# Tentative: 	24
# Rejected: 	620
# Iteration: 	23 / 100
# Confirmed: 	5
# Tentative: 	24
# Rejected: 	620
# Iteration: 	24 / 100
# Confirmed: 	5
# Tentative: 	24
# Rejected: 	620
# Iteration: 	25 / 100
# Confirmed: 	5
# Tentative: 	24
# Rejected: 	620
# Iteration: 	26 / 100
# Confirmed: 	5
# Tentative: 	24
# Rejected: 	620
# Iteration: 	27 / 100
# Confirmed: 	5
# Tentative: 	24
# Rejected: 	620
# Iteration: 	28 / 100
# Confirmed: 	5
# Tentative: 	24
# Rejected: 	620
# Iteration: 	29 / 100
# Confirmed: 	7
# Tentative: 	22
# Rejected: 	620
# Iteration: 	30 / 100
# Confirmed: 	7
# Tentative: 	22
# Rejected: 	620
# Iteration: 	31 / 100
# Confirmed: 	7
# Tentative: 	22
# Rejected: 	620
# Iteration: 	32 / 100
# Confirmed: 	9
# Tentative: 	20
# Rejected: 	620
# Iteration: 	33 / 100
# Confirmed: 	9
# Tentative: 	20
# Rejected: 	620
# Iteration: 	34 / 100
# Confirmed: 	10
# Tentative: 	19
# Rejected: 	620
# Iteration: 	35 / 100
# Confirmed: 	10
# Tentative: 	19
# Rejected: 	620
# Iteration: 	36 / 100
# Confirmed: 	10
# Tentative: 	19
# Rejected: 	620
# Iteration: 	37 / 100
# Confirmed: 	11
# Tentative: 	18
# Rejected: 	620
# Iteration: 	38 / 100
# Confirmed: 	11
# Tentative: 	18
# Rejected: 	620
# Iteration: 	39 / 100
# Confirmed: 	11
# Tentative: 	18
# Rejected: 	620
# Iteration: 	40 / 100
# Confirmed: 	13
# Tentative: 	16
# Rejected: 	620
# Iteration: 	41 / 100
# Confirmed: 	13
# Tentative: 	16
# Rejected: 	620
# Iteration: 	42 / 100
# Confirmed: 	13
# Tentative: 	16
# Rejected: 	620
# Iteration: 	43 / 100
# Confirmed: 	13
# Tentative: 	16
# Rejected: 	620
# Iteration: 	44 / 100
# Confirmed: 	13
# Tentative: 	16
# Rejected: 	620
# Iteration: 	45 / 100
# Confirmed: 	13
# Tentative: 	16
# Rejected: 	620
# Iteration: 	46 / 100
# Confirmed: 	15
# Tentative: 	13
# Rejected: 	621
# Iteration: 	47 / 100
# Confirmed: 	15
# Tentative: 	13
# Rejected: 	621
# Iteration: 	48 / 100
# Confirmed: 	15
# Tentative: 	13
# Rejected: 	621
# Iteration: 	49 / 100
# Confirmed: 	15
# Tentative: 	12
# Rejected: 	622
# Iteration: 	50 / 100
# Confirmed: 	15
# Tentative: 	12
# Rejected: 	622
# Iteration: 	51 / 100
# Confirmed: 	15
# Tentative: 	12
# Rejected: 	622
# Iteration: 	52 / 100
# Confirmed: 	15
# Tentative: 	12
# Rejected: 	622
# Iteration: 	53 / 100
# Confirmed: 	15
# Tentative: 	12
# Rejected: 	622
# Iteration: 	54 / 100
# Confirmed: 	15
# Tentative: 	12
# Rejected: 	622
# Iteration: 	55 / 100
# Confirmed: 	15
# Tentative: 	12
# Rejected: 	622
# Iteration: 	56 / 100
# Confirmed: 	15
# Tentative: 	12
# Rejected: 	622
# Iteration: 	57 / 100
# Confirmed: 	17
# Tentative: 	10
# Rejected: 	622
# Iteration: 	58 / 100
# Confirmed: 	17
# Tentative: 	10
# Rejected: 	622
# Iteration: 	59 / 100
# Confirmed: 	17
# Tentative: 	10
# Rejected: 	622
# Iteration: 	60 / 100
# Confirmed: 	17
# Tentative: 	10
# Rejected: 	622
# Iteration: 	61 / 100
# Confirmed: 	17
# Tentative: 	10
# Rejected: 	622
# Iteration: 	62 / 100
# Confirmed: 	17
# Tentative: 	10
# Rejected: 	622
# Iteration: 	63 / 100
# Confirmed: 	17
# Tentative: 	10
# Rejected: 	622
# Iteration: 	64 / 100
# Confirmed: 	17
# Tentative: 	10
# Rejected: 	622
# Iteration: 	65 / 100
# Confirmed: 	17
# Tentative: 	10
# Rejected: 	622
# Iteration: 	66 / 100
# Confirmed: 	17
# Tentative: 	10
# Rejected: 	622
# Iteration: 	67 / 100
# Confirmed: 	17
# Tentative: 	10
# Rejected: 	622
# Iteration: 	68 / 100
# Confirmed: 	17
# Tentative: 	10
# Rejected: 	622
# Iteration: 	69 / 100
# Confirmed: 	17
# Tentative: 	10
# Rejected: 	622
# Iteration: 	70 / 100
# Confirmed: 	17
# Tentative: 	10
# Rejected: 	622
# Iteration: 	71 / 100
# Confirmed: 	17
# Tentative: 	10
# Rejected: 	622
# Iteration: 	72 / 100
# Confirmed: 	17
# Tentative: 	10
# Rejected: 	622
# Iteration: 	73 / 100
# Confirmed: 	17
# Tentative: 	10
# Rejected: 	622
# Iteration: 	74 / 100
# Confirmed: 	17
# Tentative: 	10
# Rejected: 	622
# Iteration: 	75 / 100
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	622
# Iteration: 	76 / 100
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	622
# Iteration: 	77 / 100
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	622
# Iteration: 	78 / 100
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	622
# Iteration: 	79 / 100
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	622
# Iteration: 	80 / 100
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	622
# Iteration: 	81 / 100
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	622
# Iteration: 	82 / 100
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	622
# Iteration: 	83 / 100
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	622
# Iteration: 	84 / 100
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	622
# Iteration: 	85 / 100
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	622
# Iteration: 	86 / 100
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	622
# Iteration: 	87 / 100
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	622
# Iteration: 	88 / 100
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	622
# Iteration: 	89 / 100
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	622
# Iteration: 	90 / 100
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	622
# Iteration: 	91 / 100
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	622
# Iteration: 	92 / 100
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	622
# Iteration: 	93 / 100
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	622
# Iteration: 	94 / 100
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	622
# Iteration: 	95 / 100
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	622
# Iteration: 	96 / 100
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	622
# Iteration: 	97 / 100
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	622
# Iteration: 	98 / 100
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	622
# Iteration: 	99 / 100
# Confirmed: 	18
# Tentative: 	9
# Rejected: 	622
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	18
# Tentative: 	8
# Rejected: 	622
# Number of selected features:  18
# Index(['Freq.2032.95119529926', 'Freq.2649.62957976168',
#        'Freq.3151.06004403914', 'Freq.3414.71158220371',
#        'Freq.4266.3135397872', 'Freq.4305.85988898402',
#        'Freq.4422.06473425606', 'Freq.4531.11395414778',
#        'Freq.4686.40948388443', 'Freq.4823.05474215093',
#        'Freq.5085.12753419191', 'Freq.5373.45101908019',
#        'Freq.5793.20798465767', 'Freq.6115.76202989207',
#        'Freq.6823.11643549173', 'Freq.7501.51838000843',
#        'Freq.7527.68425783419', 'Freq.8943.76551923189'],
#       dtype='object')

# %%
study = optuna.create_study(
    study_name="boruta-featuresscaler-dataset-nomalizado_v2",
    storage="sqlite:///experiments.db",
    direction="maximize",
    load_if_exists=True
)

study.optimize(objective, n_trials=100)
study._storage._backend.engine.dispose()
# Out:
# [I 2022-06-21 08:10:47,572] Using an existing study with name 'boruta-featuresscaler-dataset-nomalizado_v2' instead of creating a new one.
# [I 2022-06-21 08:10:50,116] Trial 400 finished with value: 0.7918107436509141 and parameters: {'scalers': 'robust', 'lambda_l1': 0.00027096113850948606, 'lambda_l2': 2.2139443840013307e-08, 'num_leaves': 156, 'feature_fraction': 0.703823632322998, 'bagging_fraction': 0.8091520383075381, 'bagging_freq': 1, 'min_child_samples': 9, 'max_depth': 489}. Best is trial 213 with value: 0.8103478984465826.
# [I 2022-06-21 08:10:51,707] Trial 401 finished with value: 0.795222825420194 and parameters: {'scalers': 'standard', 'lambda_l1': 0.005812630361475851, 'lambda_l2': 3.6580510659283626e-08, 'num_leaves': 181, 'feature_fraction': 0.4537670813368496, 'bagging_fraction': 0.5150177402872773, 'bagging_freq': 1, 'min_child_samples': 5, 'max_depth': 395}. Best is trial 213 with value: 0.8103478984465826.
# [I 2022-06-21 08:10:53,382] Trial 402 finished with value: 0.803516403187456 and parameters: {'scalers': 'standard', 'lambda_l1': 0.0022218137472830393, 'lambda_l2': 6.322910566241332e-08, 'num_leaves': 167, 'feature_fraction': 0.6882570449689361, 'bagging_fraction': 0.5452287916101313, 'bagging_freq': 1, 'min_child_samples': 7, 'max_depth': 364}. Best is trial 213 with value: 0.8103478984465826.
# [I 2022-06-21 08:10:54,764] Trial 403 finished with value: 0.7928331509391882 and parameters: {'scalers': 'standard', 'lambda_l1': 0.0014338466510161138, 'lambda_l2': 1.224063005193294e-07, 'num_leaves': 3, 'feature_fraction': 0.7499388751575676, 'bagging_fraction': 0.5663588207835285, 'bagging_freq': 1, 'min_child_samples': 8, 'max_depth': 413}. Best is trial 213 with value: 0.8103478984465826.
# [I 2022-06-21 08:10:56,249] Trial 404 finished with value: 0.7910706930668231 and parameters: {'scalers': 'minmax', 'lambda_l1': 0.00866720047544398, 'lambda_l2': 2.522639617490546e-08, 'num_leaves': 129, 'feature_fraction': 0.7204070808538646, 'bagging_fraction': 0.4762994070653164, 'bagging_freq': 1, 'min_child_samples': 11, 'max_depth': 451}. Best is trial 213 with value: 0.8103478984465826.
# [I 2022-06-21 08:10:58,004] Trial 405 finished with value: 0.8010692757534863 and parameters: {'scalers': 'standard', 'lambda_l1': 0.00435332926469013, 'lambda_l2': 3.415630688536689e-07, 'num_leaves': 148, 'feature_fraction': 0.6750713156304978, 'bagging_fraction': 0.5217851264311071, 'bagging_freq': 1, 'min_child_samples': 5, 'max_depth': 569}. Best is trial 213 with value: 0.8103478984465826.
# [I 2022-06-21 08:10:59,560] Trial 406 finished with value: 0.8011381631354542 and parameters: {'scalers': 'standard', 'lambda_l1': 0.014977807971565988, 'lambda_l2': 6.18057364265813e-08, 'num_leaves': 87, 'feature_fraction': 0.6022534198176788, 'bagging_fraction': 0.5004788352304859, 'bagging_freq': 1, 'min_child_samples': 7, 'max_depth': 382}. Best is trial 213 with value: 0.8103478984465826.
# [I 2022-06-21 08:11:01,553] Trial 407 finished with value: 0.7862337742666691 and parameters: {'scalers': 'standard', 'lambda_l1': 0.006005263836319974, 'lambda_l2': 2.066252711132196e-07, 'num_leaves': 161, 'feature_fraction': 0.6995745382980519, 'bagging_fraction': 0.4403637304699235, 'bagging_freq': 1, 'min_child_samples': 9, 'max_depth': 505}. Best is trial 213 with value: 0.8103478984465826.
# [I 2022-06-21 08:11:03,424] Trial 408 finished with value: 0.8016327359860642 and parameters: {'scalers': 'standard', 'lambda_l1': 0.
 'bagging_freq': 1, 'min_child_samples': 8, 'max_depth': 462}. Best is trial 213 with value: 0.8103478984465826.
# [I 2022-06-21 08:13:49,242] Trial 499 finished with value: 0.8033294965268649 and parameters: {'scalers': 'standard', 'lambda_l1': 7.581057067076961e-07, 'lambda_l2': 1.8140377972389637e-07, 'num_leaves': 121, 'feature_fraction': 0.7167200520106441, 'bagging_fraction': 0.4463940037365155, 'bagging_freq': 1, 'min_child_samples': 5, 'max_depth': 243}. Best is trial 213 with value: 0.8103478984465826.

# %%
# Get best trial based on metric score
trial = study.best_trial
# Best Score from HP Opt
print(f'Best trial Score from HP Opt: {trial.values[0]:.4f}\n')

detailed_objective(trial)
# Out:
# Best trial Score from HP Opt: 0.8103
#
#     scaler: StandardScaler()
#     objective: binary
#     metric: binary_logloss
#     verbosity: -1
#     boosting_type: gbdt
#     lambda_l1: 0.0034481481436410702
#     lambda_l2: 2.3643530816733582e-08
#     num_leaves: 152
#     feature_fraction: 0.7049291692912046
#     bagging_fraction: 0.5598808081710741
#     bagging_freq: 1
#     min_child_samples: 5
#     n_estimators: 434
# [LightGBM] [Warning] feature_fraction is set=0.7049291692912046, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7049291692912046
# [LightGBM] [Warning] lambda_l1 is set=0.0034481481436410702, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0034481481436410702
# [LightGBM] [Warning] bagging_fraction is set=0.5598808081710741, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5598808081710741
# [LightGBM] [Warning] lambda_l2 is set=2.3643530816733582e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.3643530816733582e-08
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [TEST]
# balanced_accuracy: 0.6333, accuracy: 0.6875, specificity: 0.8500, sensitivity: 0.4167
# (0.6333333333333333, 0.6875, 0.85, 0.4166666666666667)

# %% [markdown]
# ```
# artigo_v2 com scaler
# ```

# %%
# Select a dataset
dataset_name = 'artigo_v2'

# Get Features and Target
X, y, X_test, y_test = getFeaturesTargets(dataset_name)

# define random forest classifier, with utilising all cores and
# sampling in proportion to y labels
rf = RandomForestClassifier(n_jobs=-1, class_weight='balanced', max_depth=5)
# define Boruta feature selection method
feat_selector = BorutaPy(rf, n_estimators='auto', verbose=2, random_state=SEED, )

feat_selector.fit(np.array(X), y)

print("Number of selected features: ", feat_selector.n_features_)

print(X.columns[feat_selector.support_])

# Filter most importante features
X_transform = feat_selector.transform(np.array(X))
X_test_transform = feat_selector.transform(np.array(X_test))

# Define objectiva funtion to maximize metric
def objective(trial):
    
    # List scalers to chose from
    scalers = trial.suggest_categorical("scalers", ['minmax', 'standard', 'robust'])
    # Define scalers
    if scalers == "minmax":
        scaler = MinMaxScaler()
    elif scalers == "standard":
        scaler = StandardScaler()
    else:
        scaler = RobustScaler()
    # LGBM Hyper Parameter Grid
    param = {
        "objective": "binary",
        "metric": "binary_logloss",
        "verbosity": -1,
        "boosting_type": "gbdt",
        "lambda_l1": trial.suggest_float("lambda_l1", 1e-8, 10.0, log=True),
        "lambda_l2": trial.suggest_float("lambda_l2", 1e-8, 10.0, log=True),
        "num_leaves": trial.suggest_int("num_leaves", 2, 256),
        "feature_fraction": trial.suggest_float("feature_fraction", 0.4, 1.0),
        "bagging_fraction": trial.suggest_float("bagging_fraction", 0.4, 1.0),
        "bagging_freq": trial.suggest_int("bagging_freq", 1, 7),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
        "n_estimators": trial.suggest_int("max_depth", 100, 1000)
    }
    # Create model pipeline with param trial
    clf = Pipeline([("scaler", scaler),
                    ("lgbm_clf", lgb.LGBMClassifier(random_state=SEED, **param))])
    # Get CV Metric we want to maximize
    balanced_accuracy = np.mean(cross_val_score(clf, X_transform, y, scoring=metric_scorer, cv=rkf, n_jobs=-1))
    
    return balanced_accuracy


# Define a detailed objective function to get more metrics of best trial
def detailed_objective(trial):
    
    # List scalers to chose from
    scalers = trial.suggest_categorical("scalers", ['minmax', 'standard', 'robust'])
    # Define scalers
    if scalers == "minmax":
        scaler = MinMaxScaler()
    elif scalers == "standard":
        scaler = StandardScaler()
    else:
        scaler = RobustScaler()
    # LGBM Hyper Parameter Grid
    param = {
        "objective": "binary",
        "metric": "binary_logloss",
        "verbosity": -1,
        "boosting_type": "gbdt",
        "lambda_l1": trial.suggest_float("lambda_l1", 1e-8, 10.0, log=True),
        "lambda_l2": trial.suggest_float("lambda_l2", 1e-8, 10.0, log=True),
        "num_leaves": trial.suggest_int("num_leaves", 2, 256),
        "feature_fraction": trial.suggest_float("feature_fraction", 0.4, 1.0),
        "bagging_fraction": trial.suggest_float("bagging_fraction", 0.4, 1.0),
        "bagging_freq": trial.suggest_int("bagging_freq", 1, 7),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
        "n_estimators": trial.suggest_int("max_depth", 100, 1000)
    }
    # Create model pipeline with param trial
    clf = Pipeline([("scaler", scaler),
                    ("lgbm_clf", lgb.LGBMClassifier(random_state=SEED, **param))])

    # Print params for best trial
    print(f"    scaler: {scaler}")
    for key, value in param.items():
        print("    {}: {}".format(key, value))


    clf.fit(X_transform, y)

    # calculate more evaluation metrics
    predicted = clf.predict(X_test_transform)

    bal_accuracy = balanced_accuracy_score(y_test, predicted)
    accuracy = accuracy_score(y_test, predicted)
    tn, fp, fn, tp = confusion_matrix(y_test, predicted).ravel()
    specificity = tn / (tn+fp)
    sensitivity  = tp / (tp+fn)

    print('[TEST]')
    print(f'balanced_accuracy: {bal_accuracy:.4f}, accuracy: {accuracy:.4f}, specificity: {specificity:.4f}, sensitivity: {sensitivity:.4f}')
    return (bal_accuracy, accuracy, specificity, sensitivity)
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	560
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	560
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	560
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	560
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	560
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	560
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	560
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	0
# Tentative: 	41
# Rejected: 	519
# Iteration: 	9 / 100
# Confirmed: 	2
# Tentative: 	39
# Rejected: 	519
# Iteration: 	10 / 100
# Confirmed: 	2
# Tentative: 	39
# Rejected: 	519
# Iteration: 	11 / 100
# Confirmed: 	2
# Tentative: 	39
# Rejected: 	519
# Iteration: 	12 / 100
# Confirmed: 	4
# Tentative: 	27
# Rejected: 	529
# Iteration: 	13 / 100
# Confirmed: 	4
# Tentative: 	27
# Rejected: 	529
# Iteration: 	14 / 100
# Confirmed: 	4
# Tentative: 	27
# Rejected: 	529
# Iteration: 	15 / 100
# Confirmed: 	4
# Tentative: 	27
# Rejected: 	529
# Iteration: 	16 / 100
# Confirmed: 	6
# Tentative: 	25
# Rejected: 	529
# Iteration: 	17 / 100
# Confirmed: 	6
# Tentative: 	25
# Rejected: 	529
# Iteration: 	18 / 100
# Confirmed: 	6
# Tentative: 	25
# Rejected: 	529
# Iteration: 	19 / 100
# Confirmed: 	6
# Tentative: 	25
# Rejected: 	529
# Iteration: 	20 / 100
# Confirmed: 	6
# Tentative: 	24
# Rejected: 	530
# Iteration: 	21 / 100
# Confirmed: 	6
# Tentative: 	24
# Rejected: 	530
# Iteration: 	22 / 100
# Confirmed: 	7
# Tentative: 	23
# Rejected: 	530
# Iteration: 	23 / 100
# Confirmed: 	7
# Tentative: 	23
# Rejected: 	530
# Iteration: 	24 / 100
# Confirmed: 	7
# Tentative: 	23
# Rejected: 	530
# Iteration: 	25 / 100
# Confirmed: 	7
# Tentative: 	23
# Rejected: 	530
# Iteration: 	26 / 100
# Confirmed: 	7
# Tentative: 	23
# Rejected: 	530
# Iteration: 	27 / 100
# Confirmed: 	7
# Tentative: 	23
# Rejected: 	530
# Iteration: 	28 / 100
# Confirmed: 	7
# Tentative: 	23
# Rejected: 	530
# Iteration: 	29 / 100
# Confirmed: 	8
# Tentative: 	22
# Rejected: 	530
# Iteration: 	30 / 100
# Confirmed: 	8
# Tentative: 	22
# Rejected: 	530
# Iteration: 	31 / 100
# Confirmed: 	8
# Tentative: 	22
# Rejected: 	530
# Iteration: 	32 / 100
# Confirmed: 	10
# Tentative: 	20
# Rejected: 	530
# Iteration: 	33 / 100
# Confirmed: 	10
# Tentative: 	20
# Rejected: 	530
# Iteration: 	34 / 100
# Confirmed: 	11
# Tentative: 	19
# Rejected: 	530
# Iteration: 	35 / 100
# Confirmed: 	11
# Tentative: 	19
# Rejected: 	530
# Iteration: 	36 / 100
# Confirmed: 	11
# Tentative: 	19
# Rejected: 	530
# Iteration: 	37 / 100
# Confirmed: 	12
# Tentative: 	18
# Rejected: 	530
# Iteration: 	38 / 100
# Confirmed: 	12
# Tentative: 	18
# Rejected: 	530
# Iteration: 	39 / 100
# Confirmed: 	12
# Tentative: 	18
# Rejected: 	530
# Iteration: 	40 / 100
# Confirmed: 	14
# Tentative: 	16
# Rejected: 	530
# Iteration: 	41 / 100
# Confirmed: 	14
# Tentative: 	16
# Rejected: 	530
# Iteration: 	42 / 100
# Confirmed: 	14
# Tentative: 	16
# Rejected: 	530
# Iteration: 	43 / 100
# Confirmed: 	14
# Tentative: 	16
# Rejected: 	530
# Iteration: 	44 / 100
# Confirmed: 	14
# Tentative: 	16
# Rejected: 	530
# Iteration: 	45 / 100
# Confirmed: 	14
# Tentative: 	16
# Rejected: 	530
# Iteration: 	46 / 100
# Confirmed: 	15
# Tentative: 	15
# Rejected: 	530
# Iteration: 	47 / 100
# Confirmed: 	15
# Tentative: 	15
# Rejected: 	530
# Iteration: 	48 / 100
# Confirmed: 	15
# Tentative: 	15
# Rejected: 	530
# Iteration: 	49 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	50 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	51 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	52 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	53 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	54 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	55 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	56 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	57 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	58 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	59 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	60 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	61 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	62 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	63 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	64 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	65 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	66 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	67 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	68 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	69 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	70 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	71 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	72 / 100
# Confirmed: 	17
# Tentative: 	13
# Rejected: 	530
# Iteration: 	73 / 100
# Confirmed: 	17
# Tentative: 	13
# Rejected: 	530
# Iteration: 	74 / 100
# Confirmed: 	17
# Tentative: 	13
# Rejected: 	530
# Iteration: 	75 / 100
# Confirmed: 	17
# Tentative: 	13
# Rejected: 	530
# Iteration: 	76 / 100
# Confirmed: 	17
# Tentative: 	13
# Rejected: 	530
# Iteration: 	77 / 100
# Confirmed: 	18
# Tentative: 	12
# Rejected: 	530
# Iteration: 	78 / 100
# Confirmed: 	18
# Tentative: 	12
# Rejected: 	530
# Iteration: 	79 / 100
# Confirmed: 	18
# Tentative: 	12
# Rejected: 	530
# Iteration: 	80 / 100
# Confirmed: 	18
# Tentative: 	12
# Rejected: 	530
# Iteration: 	81 / 100
# Confirmed: 	18
# Tentative: 	12
# Rejected: 	530
# Iteration: 	82 / 100
# Confirmed: 	18
# Tentative: 	12
# Rejected: 	530
# Iteration: 	83 / 100
# Confirmed: 	18
# Tentative: 	12
# Rejected: 	530
# Iteration: 	84 / 100
# Confirmed: 	18
# Tentative: 	12
# Rejected: 	530
# Iteration: 	85 / 100
# Confirmed: 	18
# Tentative: 	12
# Rejected: 	530
# Iteration: 	86 / 100
# Confirmed: 	18
# Tentative: 	12
# Rejected: 	530
# Iteration: 	87 / 100
# Confirmed: 	18
# Tentative: 	12
# Rejected: 	530
# Iteration: 	88 / 100
# Confirmed: 	19
# Tentative: 	11
# Rejected: 	530
# Iteration: 	89 / 100
# Confirmed: 	19
# Tentative: 	11
# Rejected: 	530
# Iteration: 	90 / 100
# Confirmed: 	19
# Tentative: 	11
# Rejected: 	530
# Iteration: 	91 / 100
# Confirmed: 	19
# Tentative: 	11
# Rejected: 	530
# Iteration: 	92 / 100
# Confirmed: 	19
# Tentative: 	11
# Rejected: 	530
# Iteration: 	93 / 100
# Confirmed: 	19
# Tentative: 	11
# Rejected: 	530
# Iteration: 	94 / 100
# Confirmed: 	19
# Tentative: 	11
# Rejected: 	530
# Iteration: 	95 / 100
# Confirmed: 	19
# Tentative: 	11
# Rejected: 	530
# Iteration: 	96 / 100
# Confirmed: 	19
# Tentative: 	11
# Rejected: 	530
# Iteration: 	97 / 100
# Confirmed: 	19
# Tentative: 	11
# Rejected: 	530
# Iteration: 	98 / 100
# Confirmed: 	20
# Tentative: 	10
# Rejected: 	530
# Iteration: 	99 / 100
# Confirmed: 	20
# Tentative: 	10
# Rejected: 	530
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	20
# Tentative: 	9
# Rejected: 	530
# Number of selected features:  20
# Index(['Freq.1514.70175609701', 'Freq.1538.31602411884',
#        'Freq.2032.98713905056', 'Freq.2100.44990262345',
#        'Freq.3083.87231952593', 'Freq.4065.18390132971',
#        'Freq.4121.12758696721', 'Freq.4266.97846896688',
#        'Freq.4283.95182164633', 'Freq.4307.03317519015',
#        'Freq.4423.09444608773', 'Freq.4530.88583193204',
#        'Freq.4659.55667096198', 'Freq.4686.73931634643',
#        'Freq.4823.08140765752', 'Freq.5084.14952111257',
#        'Freq.5272.6322523475', 'Freq.5793.12301502666',
#        'Freq.7134.78019703427', 'Freq.8943.8000787644'],
#       dtype='object')

# %%
study = optuna.create_study(
    study_name="boruta-featuresscaler-dataset-artigo_v2",
    storage="sqlite:///experiments.db",
    direction="maximize",
    load_if_exists=True
)

study.optimize(objective, n_trials=20)
study._storage._backend.engine.dispose()
# Out:
# [I 2022-06-21 11:06:08,306] Using an existing study with name 'boruta-featuresscaler-dataset-artigo_v2' instead of creating a new one.
# [I 2022-06-21 11:06:10,548] Trial 481 finished with value: 0.847306312495554 and parameters: {'scalers': 'minmax', 'lambda_l1': 3.475281353016381e-05, 'lambda_l2': 2.2036117180354706e-08, 'num_leaves': 80, 'feature_fraction': 0.4103144688495338, 'bagging_fraction': 0.5914977904912272, 'bagging_freq': 4, 'min_child_samples': 9, 'max_depth': 483}. Best is trial 294 with value: 0.8598238376690389.
# [I 2022-06-21 11:06:11,967] Trial 482 finished with value: 0.8464005130146771 and parameters: {'scalers': 'minmax', 'lambda_l1': 6.290298320799815e-05, 'lambda_l2': 3.279209064258963e-08, 'num_leaves': 74, 'feature_fraction': 0.43102767121241736, 'bagging_fraction': 0.5805406161244663, 'bagging_freq': 4, 'min_child_samples': 7, 'max_depth': 446}. Best is trial 294 with value: 0.8598238376690389.
# [I 2022-06-21 11:06:13,340] Trial 483 finished with value: 0.8365755803793731 and parameters: {'scalers': 'minmax', 'lambda_l1': 0.00018855685449702163, 'lambda_l2': 4.341098495980117e-08, 'num_leaves': 71, 'feature_fraction': 0.6421906023174783, 'bagging_fraction': 0.4001479546290648, 'bagging_freq': 4, 'min_child_samples': 10, 'max_depth': 465}. Best is trial 294 with value: 0.8598238376690389.
# [I 2022-06-21 11:06:14,834] Trial 484 finished with value: 0.8483220241231078 and parameters: {'scalers': 'minmax', 'lambda_l1': 0.00015329168342096623, 'lambda_l2': 1.4852418193551706e-08, 'num_leaves': 81, 'feature_fraction': 0.41281757672823116, 'bagging_fraction': 0.6173961929449225, 'bagging_freq': 4, 'min_child_samples': 9, 'max_depth': 508}. Best is trial 294 with value: 0.8598238376690389.
# [I 2022-06-21 11:06:16,527] Trial 485 finished with value: 0.850762329732531 and parameters: {'scalers': 'standard', 'lambda_l1': 0.00023284123680939465, 'lambda_l2': 2.479666674677913e-08, 'num_leaves': 85, 'feature_fraction': 0.41947234709406983, 'bagging_fraction': 0.6385686201914834, 'bagging_freq': 4, 'min_child_samples': 12, 'max_depth': 438}. Best is trial 294 with value: 0.8598238376690389.
# [I 2022-06-21 11:06:17,943] Trial 486 finished with value: 0.8495292243875835 and parameters: {'scalers': 'minmax', 'lambda_l1': 7.831639992691987e-05, 'lambda_l2': 5.131472055592718e-08, 'num_leaves': 63, 'feature_fraction': 0.4003975474860036, 'bagging_fraction': 0.6052657377402433, 'bagging_freq': 4, 'min_child_samples': 6, 'max_depth': 458}. Best is trial 294 with value: 0.8598238376690389.
# [I 2022-06-21 11:06
and parameters: {'scalers': 'minmax', 'lambda_l1': 0.0005930734513999291, 'lambda_l2': 3.260519880194134e-07, 'num_leaves': 69, 'feature_fraction': 0.4193381711975231, 'bagging_fraction': 0.6115481061854919, 'bagging_freq': 5, 'min_child_samples': 9, 'max_depth': 493}. Best is trial 294 with value: 0.8598238376690389.
# [I 2022-06-21 11:06:36,823] Trial 498 finished with value: 0.8318626460828473 and parameters: {'scalers': 'minmax', 'lambda_l1': 0.0024192193932617116, 'lambda_l2': 2.3022782856789337e-07, 'num_leaves': 73, 'feature_fraction': 0.45427883069251, 'bagging_fraction': 0.6301514195440535, 'bagging_freq': 4, 'min_child_samples': 5, 'max_depth': 506}. Best is trial 294 with value: 0.8598238376690389.
# [I 2022-06-21 11:06:38,887] Trial 499 finished with value: 0.8441662776937545 and parameters: {'scalers': 'minmax', 'lambda_l1': 0.0001365144000969619, 'lambda_l2': 1.4098847616085365e-07, 'num_leaves': 79, 'feature_fraction': 0.42930298097658526, 'bagging_fraction': 0.613692621036133, 'bagging_freq': 4, 'min_child_samples': 13, 'max_depth': 567}. Best is trial 294 with value: 0.8598238376690389.
# [I 2022-06-21 11:06:40,329] Trial 500 finished with value: 0.8541173939579513 and parameters: {'scalers': 'minmax', 'lambda_l1': 0.000474560864797787, 'lambda_l2': 4.641951070305302e-07, 'num_leaves': 87, 'feature_fraction': 0.4199038529500515, 'bagging_fraction': 0.6363702862557112, 'bagging_freq': 4, 'min_child_samples': 9, 'max_depth': 521}. Best is trial 294 with value: 0.8598238376690389.

# %%
# Get best trial based on metric score
trial = study.best_trial
# Best Score from HP Opt
print(f'Best trial Score from HP Opt: {trial.values[0]:.4f}\n')

detailed_objective(trial)
# Out:
# Best trial Score from HP Opt: 0.8598
#
#     scaler: MinMaxScaler()
#     objective: binary
#     metric: binary_logloss
#     verbosity: -1
#     boosting_type: gbdt
#     lambda_l1: 0.00108303951692939
#     lambda_l2: 2.1243714516894663e-07
#     num_leaves: 103
#     feature_fraction: 0.40116015489878404
#     bagging_fraction: 0.5804983211493618
#     bagging_freq: 4
#     min_child_samples: 12
#     n_estimators: 455
# [LightGBM] [Warning] feature_fraction is set=0.40116015489878404, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.40116015489878404
# [LightGBM] [Warning] lambda_l1 is set=0.00108303951692939, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.00108303951692939
# [LightGBM] [Warning] bagging_fraction is set=0.5804983211493618, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5804983211493618
# [LightGBM] [Warning] lambda_l2 is set=2.1243714516894663e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.1243714516894663e-07
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [TEST]
# balanced_accuracy: 0.7208, accuracy: 0.7656, specificity: 0.9000, sensitivity: 0.5417
# (0.7208333333333333, 0.765625, 0.9, 0.5416666666666666)

# %% [markdown]
# ```
# artigo_v2 sem scaler
# ```

# %%
# Select a dataset
dataset_name = 'artigo_v2'

# Get Features and Target
X, y, X_test, y_test = getFeaturesTargets(dataset_name)

# define random forest classifier, with utilising all cores and
# sampling in proportion to y labels
rf = RandomForestClassifier(n_jobs=-1, class_weight='balanced', max_depth=5)
# define Boruta feature selection method
feat_selector = BorutaPy(rf, n_estimators='auto', verbose=2, random_state=SEED, )

feat_selector.fit(np.array(X), y)

print("Number of selected features: ", feat_selector.n_features_)

print(X.columns[feat_selector.support_])

# Filter most importante features
X_transform = feat_selector.transform(np.array(X))
X_test_transform = feat_selector.transform(np.array(X_test))

# Define objectiva funtion to maximize metric
def objective(trial):
    
    # LGBM Hyper Parameter Grid
    param = {
        "objective": "binary",
        "metric": "binary_logloss",
        "verbosity": -1,
        "boosting_type": "gbdt",
        "lambda_l1": trial.suggest_float("lambda_l1", 1e-8, 10.0, log=True),
        "lambda_l2": trial.suggest_float("lambda_l2", 1e-8, 10.0, log=True),
        "num_leaves": trial.suggest_int("num_leaves", 2, 256),
        "feature_fraction": trial.suggest_float("feature_fraction", 0.4, 1.0),
        "bagging_fraction": trial.suggest_float("bagging_fraction", 0.4, 1.0),
        "bagging_freq": trial.suggest_int("bagging_freq", 1, 7),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
        "n_estimators": trial.suggest_int("max_depth", 100, 1000)
    }
    # Create model pipeline with param trial
    clf = Pipeline([("lgbm_clf", lgb.LGBMClassifier(random_state=SEED, **param))])
    # Get CV Metric we want to maximize
    balanced_accuracy = np.mean(cross_val_score(clf, X_transform, y, scoring=metric_scorer, cv=rkf, n_jobs=-1))
    
    return balanced_accuracy


# Define a detailed objective function to get more metrics of best trial
def detailed_objective(trial):
    
    # LGBM Hyper Parameter Grid
    param = {
        "objective": "binary",
        "metric": "binary_logloss",
        "verbosity": -1,
        "boosting_type": "gbdt",
        "lambda_l1": trial.suggest_float("lambda_l1", 1e-8, 10.0, log=True),
        "lambda_l2": trial.suggest_float("lambda_l2", 1e-8, 10.0, log=True),
        "num_leaves": trial.suggest_int("num_leaves", 2, 256),
        "feature_fraction": trial.suggest_float("feature_fraction", 0.4, 1.0),
        "bagging_fraction": trial.suggest_float("bagging_fraction", 0.4, 1.0),
        "bagging_freq": trial.suggest_int("bagging_freq", 1, 7),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
        "n_estimators": trial.suggest_int("max_depth", 100, 1000)
    }
    # Create model pipeline with param trial
    clf = Pipeline([("lgbm_clf", lgb.LGBMClassifier(random_state=SEED, **param))])

    # Print params for best trial
    for key, value in param.items():
        print("    {}: {}".format(key, value))


    clf.fit(X_transform, y)

    # calculate more evaluation metrics
    predicted = clf.predict(X_test_transform)

    bal_accuracy = balanced_accuracy_score(y_test, predicted)
    accuracy = accuracy_score(y_test, predicted)
    tn, fp, fn, tp = confusion_matrix(y_test, predicted).ravel()
    specificity = tn / (tn+fp)
    sensitivity  = tp / (tp+fn)

    print('[TEST]')
    print(f'balanced_accuracy: {bal_accuracy:.4f}, accuracy: {accuracy:.4f}, specificity: {specificity:.4f}, sensitivity: {sensitivity:.4f}')
    return (bal_accuracy, accuracy, specificity, sensitivity)
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	560
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	560
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	560
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	560
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	560
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	560
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	560
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	0
# Tentative: 	41
# Rejected: 	519
# Iteration: 	9 / 100
# Confirmed: 	2
# Tentative: 	39
# Rejected: 	519
# Iteration: 	10 / 100
# Confirmed: 	2
# Tentative: 	39
# Rejected: 	519
# Iteration: 	11 / 100
# Confirmed: 	2
# Tentative: 	39
# Rejected: 	519
# Iteration: 	12 / 100
# Confirmed: 	4
# Tentative: 	27
# Rejected: 	529
# Iteration: 	13 / 100
# Confirmed: 	4
# Tentative: 	27
# Rejected: 	529
# Iteration: 	14 / 100
# Confirmed: 	4
# Tentative: 	27
# Rejected: 	529
# Iteration: 	15 / 100
# Confirmed: 	4
# Tentative: 	27
# Rejected: 	529
# Iteration: 	16 / 100
# Confirmed: 	6
# Tentative: 	25
# Rejected: 	529
# Iteration: 	17 / 100
# Confirmed: 	6
# Tentative: 	25
# Rejected: 	529
# Iteration: 	18 / 100
# Confirmed: 	6
# Tentative: 	25
# Rejected: 	529
# Iteration: 	19 / 100
# Confirmed: 	6
# Tentative: 	25
# Rejected: 	529
# Iteration: 	20 / 100
# Confirmed: 	6
# Tentative: 	24
# Rejected: 	530
# Iteration: 	21 / 100
# Confirmed: 	6
# Tentative: 	24
# Rejected: 	530
# Iteration: 	22 / 100
# Confirmed: 	7
# Tentative: 	23
# Rejected: 	530
# Iteration: 	23 / 100
# Confirmed: 	7
# Tentative: 	23
# Rejected: 	530
# Iteration: 	24 / 100
# Confirmed: 	7
# Tentative: 	23
# Rejected: 	530
# Iteration: 	25 / 100
# Confirmed: 	7
# Tentative: 	23
# Rejected: 	530
# Iteration: 	26 / 100
# Confirmed: 	7
# Tentative: 	23
# Rejected: 	530
# Iteration: 	27 / 100
# Confirmed: 	7
# Tentative: 	23
# Rejected: 	530
# Iteration: 	28 / 100
# Confirmed: 	7
# Tentative: 	23
# Rejected: 	530
# Iteration: 	29 / 100
# Confirmed: 	8
# Tentative: 	22
# Rejected: 	530
# Iteration: 	30 / 100
# Confirmed: 	8
# Tentative: 	22
# Rejected: 	530
# Iteration: 	31 / 100
# Confirmed: 	8
# Tentative: 	22
# Rejected: 	530
# Iteration: 	32 / 100
# Confirmed: 	10
# Tentative: 	20
# Rejected: 	530
# Iteration: 	33 / 100
# Confirmed: 	10
# Tentative: 	20
# Rejected: 	530
# Iteration: 	34 / 100
# Confirmed: 	11
# Tentative: 	19
# Rejected: 	530
# Iteration: 	35 / 100
# Confirmed: 	11
# Tentative: 	19
# Rejected: 	530
# Iteration: 	36 / 100
# Confirmed: 	11
# Tentative: 	19
# Rejected: 	530
# Iteration: 	37 / 100
# Confirmed: 	12
# Tentative: 	18
# Rejected: 	530
# Iteration: 	38 / 100
# Confirmed: 	12
# Tentative: 	18
# Rejected: 	530
# Iteration: 	39 / 100
# Confirmed: 	12
# Tentative: 	18
# Rejected: 	530
# Iteration: 	40 / 100
# Confirmed: 	14
# Tentative: 	16
# Rejected: 	530
# Iteration: 	41 / 100
# Confirmed: 	14
# Tentative: 	16
# Rejected: 	530
# Iteration: 	42 / 100
# Confirmed: 	14
# Tentative: 	16
# Rejected: 	530
# Iteration: 	43 / 100
# Confirmed: 	14
# Tentative: 	16
# Rejected: 	530
# Iteration: 	44 / 100
# Confirmed: 	14
# Tentative: 	16
# Rejected: 	530
# Iteration: 	45 / 100
# Confirmed: 	14
# Tentative: 	16
# Rejected: 	530
# Iteration: 	46 / 100
# Confirmed: 	15
# Tentative: 	15
# Rejected: 	530
# Iteration: 	47 / 100
# Confirmed: 	15
# Tentative: 	15
# Rejected: 	530
# Iteration: 	48 / 100
# Confirmed: 	15
# Tentative: 	15
# Rejected: 	530
# Iteration: 	49 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	50 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	51 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	52 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	53 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	54 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	55 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	56 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	57 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	58 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	59 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	60 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	61 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	62 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	63 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	64 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	65 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	66 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	67 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	68 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	69 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	70 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	71 / 100
# Confirmed: 	16
# Tentative: 	14
# Rejected: 	530
# Iteration: 	72 / 100
# Confirmed: 	17
# Tentative: 	13
# Rejected: 	530
# Iteration: 	73 / 100
# Confirmed: 	17
# Tentative: 	13
# Rejected: 	530
# Iteration: 	74 / 100
# Confirmed: 	17
# Tentative: 	13
# Rejected: 	530
# Iteration: 	75 / 100
# Confirmed: 	17
# Tentative: 	13
# Rejected: 	530
# Iteration: 	76 / 100
# Confirmed: 	17
# Tentative: 	13
# Rejected: 	530
# Iteration: 	77 / 100
# Confirmed: 	18
# Tentative: 	12
# Rejected: 	530
# Iteration: 	78 / 100
# Confirmed: 	18
# Tentative: 	12
# Rejected: 	530
# Iteration: 	79 / 100
# Confirmed: 	18
# Tentative: 	12
# Rejected: 	530
# Iteration: 	80 / 100
# Confirmed: 	18
# Tentative: 	12
# Rejected: 	530
# Iteration: 	81 / 100
# Confirmed: 	18
# Tentative: 	12
# Rejected: 	530
# Iteration: 	82 / 100
# Confirmed: 	18
# Tentative: 	12
# Rejected: 	530
# Iteration: 	83 / 100
# Confirmed: 	18
# Tentative: 	12
# Rejected: 	530
# Iteration: 	84 / 100
# Confirmed: 	18
# Tentative: 	12
# Rejected: 	530
# Iteration: 	85 / 100
# Confirmed: 	18
# Tentative: 	12
# Rejected: 	530
# Iteration: 	86 / 100
# Confirmed: 	18
# Tentative: 	12
# Rejected: 	530
# Iteration: 	87 / 100
# Confirmed: 	18
# Tentative: 	12
# Rejected: 	530
# Iteration: 	88 / 100
# Confirmed: 	19
# Tentative: 	11
# Rejected: 	530
# Iteration: 	89 / 100
# Confirmed: 	19
# Tentative: 	11
# Rejected: 	530
# Iteration: 	90 / 100
# Confirmed: 	19
# Tentative: 	11
# Rejected: 	530
# Iteration: 	91 / 100
# Confirmed: 	19
# Tentative: 	11
# Rejected: 	530
# Iteration: 	92 / 100
# Confirmed: 	19
# Tentative: 	11
# Rejected: 	530
# Iteration: 	93 / 100
# Confirmed: 	19
# Tentative: 	11
# Rejected: 	530
# Iteration: 	94 / 100
# Confirmed: 	19
# Tentative: 	11
# Rejected: 	530
# Iteration: 	95 / 100
# Confirmed: 	19
# Tentative: 	11
# Rejected: 	530
# Iteration: 	96 / 100
# Confirmed: 	19
# Tentative: 	11
# Rejected: 	530
# Iteration: 	97 / 100
# Confirmed: 	19
# Tentative: 	11
# Rejected: 	530
# Iteration: 	98 / 100
# Confirmed: 	20
# Tentative: 	10
# Rejected: 	530
# Iteration: 	99 / 100
# Confirmed: 	20
# Tentative: 	10
# Rejected: 	530
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	20
# Tentative: 	9
# Rejected: 	530
# Number of selected features:  20
# Index(['Freq.1514.70175609701', 'Freq.1538.31602411884',
#        'Freq.2032.98713905056', 'Freq.2100.44990262345',
#        'Freq.3083.87231952593', 'Freq.4065.18390132971',
#        'Freq.4121.12758696721', 'Freq.4266.97846896688',
#        'Freq.4283.95182164633', 'Freq.4307.03317519015',
#        'Freq.4423.09444608773', 'Freq.4530.88583193204',
#        'Freq.4659.55667096198', 'Freq.4686.73931634643',
#        'Freq.4823.08140765752', 'Freq.5084.14952111257',
#        'Freq.5272.6322523475', 'Freq.5793.12301502666',
#        'Freq.7134.78019703427', 'Freq.8943.8000787644'],
#       dtype='object')

# %%
study = optuna.create_study(
    study_name="boruta-dataset-artigo_v2",
    storage="sqlite:///experiments.db",
    direction="maximize",
    load_if_exists=True
)

study.optimize(objective, n_trials=100)
study._storage._backend.engine.dispose()
# Out:
# [I 2022-06-21 22:40:52,104] Using an existing study with name 'boruta-dataset-artigo_v2' instead of creating a new one.
# [I 2022-06-21 22:40:55,082] Trial 400 finished with value: 0.8491278896112487 and parameters: {'lambda_l1': 1.4427153197852581e-08, 'lambda_l2': 6.0278463855587e-07, 'num_leaves': 233, 'feature_fraction': 0.6745637896537282, 'bagging_fraction': 0.4958665892033316, 'bagging_freq': 1, 'min_child_samples': 14, 'max_depth': 836}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:40:56,803] Trial 401 finished with value: 0.8368561999146366 and parameters: {'lambda_l1': 2.8691587816263718e-08, 'lambda_l2': 3.5760413898827236e-07, 'num_leaves': 187, 'feature_fraction': 0.6929259037749645, 'bagging_fraction': 0.6075351177635184, 'bagging_freq': 1, 'min_child_samples': 11, 'max_depth': 745}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:40:59,026] Trial 402 finished with value: 0.8270748964228066 and parameters: {'lambda_l1': 1.9630787733053623e-08, 'lambda_l2': 8.516282724650972, 'num_leaves': 175, 'feature_fraction': 0.6506040626414007, 'bagging_fraction': 0.45845917869047853, 'bagging_freq': 1, 'min_child_samples': 8, 'max_depth': 811}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:41
. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:41:25,588] Trial 414 finished with value: 0.8508925508186345 and parameters: {'lambda_l1': 3.17601469456908e-08, 'lambda_l2': 2.5013556048240476e-06, 'num_leaves': 229, 'feature_fraction': 0.9010964743504578, 'bagging_fraction': 0.43208282118453023, 'bagging_freq': 1, 'min_child_samples': 9, 'max_depth': 804}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:41:27,614] Trial 415 finished with value: 0.8370069427476546 and parameters: {'lambda_l1': 1.0063921338973824e-08, 'lambda_l2': 2.879350178238452e-07, 'num_leaves': 238, 'feature_fraction': 0.6423915363872625, 'bagging_fraction': 0.7566645140352469, 'bagging_freq': 1, 'min_child_samples': 11, 'max_depth': 776}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:41:29,539] Trial 416 finished with value: 0.8420671340183725 and parameters: {'lambda_l1': 8.635391248670251e-06, 'lambda_l2': 0.2056611604536742, 'num_leaves': 223, 'feature_fraction': 0.6036643110004802, 'bagging_fraction': 0.4617573942086996, 'bagging_freq': 1, 'min_child_samples': 14, 'max_depth': 699}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:41:30,499] Trial 417 finished with value: 0.5 and parameters: {'lambda_l1': 1.8561461979164877e-08, 'lambda_l2': 1.3688504174393716e-06, 'num_leaves': 23, 'feature_fraction': 0.5923943370253382, 'bagging_fraction': 0.44288188084016733, 'bagging_freq': 1, 'min_child_samples': 47, 'max_depth': 638}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:41:33,924] Trial 418 finished with value: 0.8245883931599876 and parameters: {'lambda_l1': 1.020351799955007e-08, 'lambda_l2': 0.08762508059183505, 'num_leaves': 214, 'feature_fraction': 0.6188176649090699, 'bagging_fraction': 0.8034279297414006, 'bagging_freq': 1, 'min_child_samples': 9, 'max_depth': 761}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:41:36,003] Trial 419 finished with value: 0.8454806018285121 and parameters: {'lambda_l1': 6.245340906922191e-08, 'lambda_l2': 4.7465761761038515e-07, 'num_leaves': 230, 'feature_fraction': 0.576331261715949, 'bagging_fraction': 0.4212653936515097, 'bagging_freq': 1, 'min_child_samples': 8, 'max_depth': 728}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:41:38,153] Trial 420 finished with value: 0.8485917982516281 and parameters: {'lambda_l1': 2.2914678810500446e-08, 'lambda_l2': 4.184203822292318e-05, 'num_leaves': 218, 'feature_fraction': 0.5584278422036931, 'bagging_fraction': 0.4544104352790713, 'bagging_freq': 1, 'min_child_samples': 16, 'max_depth': 776}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:41:40,024] Trial 421 finished with value: 0.8533655361666197 and parameters: {'lambda_l1': 3.7231316406498343e-08, 'lambda_l2': 7.358115224368411e-08, 'num_leaves': 224, 'feature_fraction': 0.6060387225782393, 'bagging_fraction': 0.43117975071710135, 'bagging_freq': 7, 'min_child_samples': 12, 'max_depth': 797}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:41:43,372] Trial 422 finished with value: 0.8186027270802811 and parameters: {'lambda_l1': 3.7971825772595227e-08, 'lambda_l2': 4.7759084513866465e-08, 'num_leaves': 234, 'feature_fraction': 0.6357785125572973, 'bagging_fraction': 0.47073391451966756, 'bagging_freq': 6, 'min_child_samples': 5, 'max_depth': 814}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:41:45,335] Trial 423 finished with value: 0.8460738213454931 and parameters: {'lambda_l1': 3.124266668647234e-08, 'lambda_l2': 5.834378390616931e-08, 'num_leaves': 242, 'feature_fraction': 0.6058681122423724, 'bagging_fraction': 0.4363280883810846, 'bagging_freq': 7, 'min_child_samples': 12, 'max_depth': 790}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:41:47,203] Trial 424 finished with value: 0.8488756543164437 and parameters: {'lambda_l1': 5.1271271727458444e-08, 'lambda_l2': 3.499174938426842e-08, 'num_leaves': 225, 'feature_fraction': 0.6210107980110161, 'bagging_fraction': 0.4491058485788532, 'bagging_freq': 2, 'min_child_samples': 11, 'max_depth': 824}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:41:49,160] Trial 425 finished with value: 0.8380927792967268 and parameters: {'lambda_l1': 1.744981553952943e-08, 'lambda_l2': 7.320350460153699e-08, 'num_leaves': 218, 'feature_fraction': 0.6144807384676498, 'bagging_fraction': 0.4303350770921903, 'bagging_freq': 7, 'min_child_samples': 20, 'max_depth': 803}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:41:49,946] Trial 426 finished with value: 0.8302675942478576 and parameters: {'lambda_l1': 1.5501673147571867e-08, 'lambda_l2': 1.3067348616275367e-05, 'num_leaves': 212, 'feature_fraction': 0.5974444967530639, 'bagging_fraction': 0.4866523024252222, 'bagging_freq': 1, 'min_child_samples': 14, 'max_depth': 124}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:41:51,870] Trial 427 finished with value: 0.8564073576492308 and parameters: {'lambda_l1': 2.5750843265619543e-08, 'lambda_l2': 9.229559914011068e-08, 'num_leaves': 86, 'feature_fraction': 0.5268190796805994, 'bagging_fraction': 0.43982718635165047, 'bagging_freq': 1, 'min_child_samples': 8, 'max_depth': 794}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:41:54,151] Trial 428 finished with value: 0.8484442111466106 and parameters: {'lambda_l1': 2.1307120611308703e-08, 'lambda_l2': 1.3398536892425046e-07, 'num_leaves': 83, 'feature_fraction': 0.5250361257010887, 'bagging_fraction': 0.46176857398457977, 'bagging_freq': 1, 'min_child_samples': 7, 'max_depth': 748}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:41:56,000] Trial 429 finished with value: 0.8329832338284351 and parameters: {'lambda_l1': 1.513460073288204e-08, 'lambda_l2': 1.6204141523712202e-08, 'num_leaves': 101, 'feature_fraction': 0.520250241964033, 'bagging_fraction': 0.4501750816795916, 'bagging_freq': 3, 'min_child_samples': 5, 'max_depth': 590}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:41:57,894] Trial 430 finished with value: 0.850710989088311 and parameters: {'lambda_l1': 1.0329334134322625e-08, 'lambda_l2': 9.941403132795333e-08, 'num_leaves': 82, 'feature_fraction': 0.5318180022071032, 'bagging_fraction': 0.442199802603897, 'bagging_freq': 1, 'min_child_samples': 8, 'max_depth': 713}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:41:59,739] Trial 431 finished with value: 0.8464805734770904 and parameters: {'lambda_l1': 0.19482216007850883, 'lambda_l2': 4.233441870142218e-06, 'num_leaves': 71, 'feature_fraction': 0.5171608653776307, 'bagging_fraction': 0.42200152386186407, 'bagging_freq': 1, 'min_child_samples': 9, 'max_depth': 670}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:42:01,773] Trial 432 finished with value: 0.8478973101202203 and parameters: {'lambda_l1': 2.5134113102181566e-08, 'lambda_l2': 8.270756212671886e-07, 'num_leaves': 89, 'feature_fraction': 0.5416362761558747, 'bagging_fraction': 0.4405724052549773, 'bagging_freq': 1, 'min_child_samples': 7, 'max_depth': 820}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:42:03,746] Trial 433 finished with value: 0.8497849270182861 and parameters: {'lambda_l1': 1.4836006521923373e-08, 'lambda_l2': 1.921390122254693e-07, 'num_leaves': 197, 'feature_fraction': 0.5463048655317927, 'bagging_fraction': 0.4680297283340274, 'bagging_freq': 1, 'min_child_samples': 10, 'max_depth': 791}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:42:06,062] Trial 434 finished with value: 0.8462291172020275 and parameters: {'lambda_l1': 2.761123918816517e-08, 'lambda_l2': 1.0709877353218406e-07, 'num_leaves': 204, 'feature_fraction': 0.5096083911010979, 'bagging_fraction': 0.454997429501959, 'bagging_freq': 1, 'min_child_samples': 7, 'max_depth': 692}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:42:08,125] Trial 435 finished with value: 0.8538995382842133 and parameters: {'lambda_l1': 1.0126274405306004e-08, 'lambda_l2': 1.0866809957755888e-06, 'num_leaves': 89, 'feature_fraction': 0.529393683283996, 'bagging_fraction': 0.42435643289396907, 'bagging_freq': 1, 'min_child_samples': 10, 'max_depth': 769}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:42:10,336] Trial 436 finished with value: 0.8484828644867345 and parameters: {'lambda_l1': 5.3544823242172636e-08, 'lambda_l2': 1.7784095376849267e-06, 'num_leaves': 89, 'feature_fraction': 0.5312033539642782, 'bagging_fraction': 0.4213124450381723, 'bagging_freq': 1, 'min_child_samples': 9, 'max_depth': 777}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:42:12,294] Trial 437 finished with value: 0.8446263541669888 and parameters: {'lambda_l1': 1.4885881113458217e-08, 'lambda_l2': 9.753656112467645e-07, 'num_leaves': 84, 'feature_fraction': 0.522969918373592, 'bagging_fraction': 0.4138429815420892, 'bagging_freq': 1, 'min_child_samples': 5, 'max_depth': 805}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:42:15,399] Trial 438 finished with value: 0.8277677652584772 and parameters: {'lambda_l1': 2.1715320687579136e-08, 'lambda_l2': 0.8736763069908965, 'num_leaves': 90, 'feature_fraction': 0.5420206037683069, 'bagging_fraction': 0.9001810151091335, 'bagging_freq': 1, 'min_child_samples': 10, 'max_depth': 839}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:42:16,272] Trial 439 finished with value: 0.5 and parameters: {'lambda_l1': 3.433887479178016e-08, 'lambda_l2': 1.8459939960175558e-06, 'num_leaves': 88, 'feature_fraction': 0.5375539816776783, 'bagging_fraction': 0.43976615901352806, 'bagging_freq': 1, 'min_child_samples': 74, 'max_depth': 784}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:42:18,233] Trial 440 finished with value: 0.8503769179307105 and parameters: {'lambda_l1': 7.420295479776403e-08, 'lambda_l2': 1.2077179122435703e-06, 'num_leaves': 79, 'feature_fraction': 0.5291395247980233, 'bagging_fraction': 0.4283667330318112, 'bagging_freq': 1, 'min_child_samples': 8, 'max_depth': 762}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:42:20,055] Trial 441 finished with value: 0.8514711627381907 and parameters: {'lambda_l1': 1.417282734816244e-08, 'lambda_l2': 3.3022019648211813e-06, 'num_leaves': 74, 'feature_fraction': 0.5143263310840883, 'bagging_fraction': 0.5423195770823775, 'bagging_freq': 1, 'min_child_samples': 11, 'max_depth': 824}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:42:21,991] Trial 442 finished with value: 0.8450113986460737 and parameters: {'lambda_l1': 2.3426655221192365e-08, 'lambda_l2': 7.250366945828488e-07, 'num_leaves': 95, 'feature_fraction': 0.5587573349817581, 'bagging_fraction': 0.45039536457215146, 'bagging_freq': 1, 'min_child_samples': 8, 'max_depth': 770}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:42:24,326] Trial 443 finished with value: 0.8502350608198131 and parameters: {'lambda_l1': 4.509019173334184e-08, 'lambda_l2': 5.696790709839646e-07, 'num_leaves': 109, 'feature_fraction': 0.5472498188963073, 'bagging_fraction': 0.41920029890359467, 'bagging_freq': 1, 'min_child_samples': 10, 'max_depth': 804}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:42:26,512] Trial 444 finished with value: 0.847339580268373 and parameters: {'lambda_l1': 1.0092588320745118e-08, 'lambda_l2': 1.1714788713804703e-06, 'num_leaves': 182, 'feature_fraction': 0.5127296708669858, 'bagging_fraction': 0.436350330317394, 'bagging_freq': 1, 'min_child_samples': 6, 'max_depth': 739}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:42:28,452] Trial 445 finished with value: 0.8529903306617703 and parameters: {'lambda_l1': 9.703405502283557e-08, 'lambda_l2': 3.4730704808081313e-07, 'num_leaves': 97, 'feature_fraction': 0.5579680675204596, 'bagging_fraction': 0.41319773068455645, 'bagging_freq': 1, 'min_child_samples': 12, 'max_depth': 787}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:42:30,553] Trial 446 finished with value: 0.8494621311351187 and parameters: {'lambda_l1': 1.9434977824080893e-08, 'lambda_l2': 5.726768436433837e-07, 'num_leaves': 87, 'feature_fraction': 0.528570867769041, 'bagging_fraction': 0.46081137190344895, 'bagging_freq': 1, 'min_child_samples': 9, 'max_depth': 720}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:42:32,686] Trial 447 finished with value: 0.8453479150708253 and parameters: {'lambda_l1': 3.2664119108586185e-08, 'lambda_l2': 3.532285100675837e-08, 'num_leaves': 94, 'feature_fraction': 0.5734232151386217, 'bagging_fraction': 0.42685827209460137, 'bagging_freq': 1, 'min_child_samples': 15, 'max_depth': 757}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:42:35,596] Trial 448 finished with value: 0.8557783512926701 and parameters: {'lambda_l1': 1.5215085870209435e-08, 'lambda_l2': 1.1365706888134996e-06, 'num_leaves': 247, 'feature_fraction': 0.5520622059517728, 'bagging_fraction': 0.4439879998674213, 'bagging_freq': 2, 'min_child_samples': 7, 'max_depth': 814}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:42:38,345] Trial 449 finished with value: 0.8412667054737488 and parameters: {'lambda_l1': 3.023763035223032e-08, 'lambda_l2': 1.2813407655355079e-06, 'num_leaves': 248, 'feature_fraction': 0.5465677996120589, 'bagging_fraction': 0.4680956895515937, 'bagging_freq': 2, 'min_child_samples': 5, 'max_depth': 844}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:42:41,000] Trial 450 finished with value: 0.8398537250503195 and parameters: {'lambda_l1': 2.0236617306097224e-08, 'lambda_l2': 1.0611946298880863e-06, 'num_leaves': 253, 'feature_fraction': 0.5511238258235454, 'bagging_fraction': 0.4789579114733067, 'bagging_freq': 3, 'min_child_samples': 7, 'max_depth': 860}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:42:43,124] Trial 451 finished with value: 0.8454285848310615 and parameters: {'lambda_l1': 4.425377925630611e-08, 'lambda_l2': 1.360810966302407e-07, 'num_leaves': 76, 'feature_fraction': 0.5309812364160749, 'bagging_fraction': 0.5144427716987434, 'bagging_freq': 2, 'min_child_samples': 7, 'max_depth': 654}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:42:45,107] Trial 452 finished with value: 0.8539883018598189 and parameters: {'lambda_l1': 1.5098593450485124e-08, 'lambda_l2': 1.7594327839576578e-06, 'num_leaves': 244, 'feature_fraction': 0.5622784692905525, 'bagging_fraction': 0.4530312985885931, 'bagging_freq': 2, 'min_child_samples': 8, 'max_depth': 828}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:42:47,312] Trial 453 finished with value: 0.847511474163951 and parameters: {'lambda_l1': 2.8277923086367545e-08, 'lambda_l2': 3.505360081475836e-06, 'num_leaves': 241, 'feature_fraction': 0.5598856089457924, 'bagging_fraction': 0.45805335836442923, 'bagging_freq': 2, 'min_child_samples': 6, 'max_depth': 833}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:42:49,517] Trial 454 finished with value: 0.8466201144916314 and parameters: {'lambda_l1': 5.273856622314156e-08, 'lambda_l2': 1.8533538899335252e-06, 'num_leaves': 251, 'feature_fraction': 0.5379060966095712, 'bagging_fraction': 0.49017824145740296, 'bagging_freq': 3, 'min_child_samples': 8, 'max_depth': 870}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:42:51,884] Trial 455 finished with value: 0.840083409366691 and parameters: {'lambda_l1': 1.6574377934774057e-08, 'lambda_l2': 2.3349498202058148e-06, 'num_leaves': 241, 'feature_fraction': 0.5661823419243093, 'bagging_fraction': 0.4519048683333866, 'bagging_freq': 2, 'min_child_samples': 5, 'max_depth': 822}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:42:53,752] Trial 456 finished with value: 0.8499458331056627 and parameters: {'lambda_l1': 2.2580471867444558e-08, 'lambda_l2': 2.6358542014565645e-06, 'num_leaves': 246, 'feature_fraction': 0.5515127629938704, 'bagging_fraction': 0.44728890922019005, 'bagging_freq': 2, 'min_child_samples': 9, 'max_depth': 532}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:42:55,757] Trial 457 finished with value: 0.846977494254971 and parameters: {'lambda_l1': 1.495251963180024e-08, 'lambda_l2': 1.2405580887892774e-06, 'num_leaves': 247, 'feature_fraction': 0.5397422689474076, 'bagging_fraction': 0.46874227704155996, 'bagging_freq': 3, 'min_child_samples': 7, 'max_depth': 840}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:42:58,317] Trial 458 finished with value: 0.8567921159078281 and parameters: {'lambda_l1': 7.24703483898346e-08, 'lambda_l2': 6.632800053432968e-05, 'num_leaves': 254, 'feature_fraction': 0.5702832331579208, 'bagging_fraction': 0.44296676841868216, 'bagging_freq': 2, 'min_child_samples': 10, 'max_depth': 816}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:43:00,806] Trial 459 finished with value: 0.8464855319688911 and parameters: {'lambda_l1': 9.508555564430314e-08, 'lambda_l2': 0.00010456278383611836, 'num_leaves': 256, 'feature_fraction': 0.5692511604012991, 'bagging_fraction': 0.45953048248595985, 'bagging_freq': 3, 'min_child_samples': 8, 'max_depth': 846}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:43:03,080] Trial 460 finished with value: 0.8452562022600723 and parameters: {'lambda_l1': 7.175650039241845e-08, 'lambda_l2': 1.4607066784062585e-08, 'num_leaves': 251, 'feature_fraction': 0.5672142848962811, 'bagging_fraction': 0.472825885149308, 'bagging_freq': 2, 'min_child_samples': 10, 'max_depth': 813}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:43:05,042] Trial 461 finished with value: 0.8427700058369564 and parameters: {'lambda_l1': 6.031594897301822e-08, 'lambda_l2': 0.0001736053104539508, 'num_leaves': 253, 'feature_fraction': 0.5532666263921964, 'bagging_fraction': 0.44653724545472007, 'bagging_freq': 2, 'min_child_samples': 5, 'max_depth': 826}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:43:07,054] Trial 462 finished with value: 0.8480710638690515 and parameters: {'lambda_l1': 4.108832162331777e-08, 'lambda_l2': 5.515204140033546e-08, 'num_leaves': 246, 'feature_fraction': 0.5774970921906781, 'bagging_fraction': 0.4390652646544786, 'bagging_freq': 2, 'min_child_samples': 7, 'max_depth': 855}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:43:09,120] Trial 463 finished with value: 0.8535337708816811 and parameters: {'lambda_l1': 3.8466527086989424e-08, 'lambda_l2': 9.152513952981643e-08, 'num_leaves': 256, 'feature_fraction': 0.5634402361535797, 'bagging_fraction': 0.4538008894488368, 'bagging_freq': 2, 'min_child_samples': 10, 'max_depth': 890}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:43:11,205] Trial 464 finished with value: 0.8406345316620086 and parameters: {'lambda_l1': 3.198994212443939e-05, 'lambda_l2': 3.0963906697519096e-05, 'num_leaves': 245, 'feature_fraction': 0.5823068576095763, 'bagging_fraction': 0.480203393306694, 'bagging_freq': 2, 'min_child_samples': 9, 'max_depth': 804}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:43:13,146] Trial 465 finished with value: 0.851808223767976 and parameters: {'lambda_l1': 1.0564218882972058e-07, 'lambda_l2': 7.931411639701043e-05, 'num_leaves': 241, 'feature_fraction': 0.5578912796978563, 'bagging_fraction': 0.4430887740526299, 'bagging_freq': 2, 'min_child_samples': 11, 'max_depth': 819}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:43:15,318] Trial 466 finished with value: 0.8482578203530217 and parameters: {'lambda_l1': 5.976878584700153e-08, 'lambda_l2': 0.0002541014960551015, 'num_leaves': 250, 'feature_fraction': 0.6651908974612031, 'bagging_fraction': 0.462857804460317, 'bagging_freq': 2, 'min_child_samples': 7, 'max_depth': 799}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:43:17,184] Trial 467 finished with value: 0.8534196283163001 and parameters: {'lambda_l1': 3.234768643321336e-08, 'lambda_l2': 2.8756802180354785e-08, 'num_leaves': 237, 'feature_fraction': 0.5742907598373095, 'bagging_fraction': 0.44054638073468394, 'bagging_freq': 2, 'min_child_samples': 11, 'max_depth': 834}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:43:17,894] Trial 468 finished with value: 0.5 and parameters: {'lambda_l1': 2.620881684328547e-08, 'lambda_l2': 6.194506124221981e-06, 'num_leaves': 256, 'feature_fraction': 0.7103577689984508, 'bagging_fraction': 0.4548321881631104, 'bagging_freq': 2, 'min_child_samples': 50, 'max_depth': 288}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:43:19,976] Trial 469 finished with value: 0.8490745556902677 and parameters: {'lambda_l1': 0.0014264753250451706, 'lambda_l2': 1.0160249428082727e-08, 'num_leaves': 244, 'feature_fraction': 0.549804349948826, 'bagging_fraction': 0.5659607889415, 'bagging_freq': 2, 'min_child_samples': 8, 'max_depth': 875}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:43:22,003] Trial 470 finished with value: 0.8475023136048679 and parameters: {'lambda_l1': 4.263915735298118e-08, 'lambda_l2': 0.0005854080849605141, 'num_leaves': 234, 'feature_fraction': 0.564992226057067, 'bagging_fraction': 0.4380174233657627, 'bagging_freq': 2, 'min_child_samples': 12, 'max_depth': 799}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:43:24,125] Trial 471 finished with value: 0.8539018888747989 and parameters: {'lambda_l1': 2.429177208771055e-08, 'lambda_l2': 5.085487052464468e-05, 'num_leaves': 249, 'feature_fraction': 0.57777450983882, 'bagging_fraction': 0.4341348818394824, 'bagging_freq': 3, 'min_child_samples': 9, 'max_depth': 821}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:43:26,158] Trial 472 finished with value: 0.8422110195016542 and parameters: {'lambda_l1': 8.181896178686919e-08, 'lambda_l2': 1.5525540940519376e-05, 'num_leaves': 238, 'feature_fraction': 0.5856574891556781, 'bagging_fraction': 0.44831075396544257, 'bagging_freq': 1, 'min_child_samples': 6, 'max_depth': 787}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:43:28,020] Trial 473 finished with value: 0.8559781208643438 and parameters: {'lambda_l1': 2.148635353955212e-08, 'lambda_l2': 1.1511406653200925e-05, 'num_leaves': 243, 'feature_fraction': 0.5677096827710305, 'bagging_fraction': 0.5003232552370022, 'bagging_freq': 2, 'min_child_samples': 11, 'max_depth': 681}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:43:29,946] Trial 474 finished with value: 0.8466761536537077 and parameters: {'lambda_l1': 1.9018271991718982e-08, 'lambda_l2': 1.9917540182010403e-06, 'num_leaves': 252, 'feature_fraction': 0.9439489492662327, 'bagging_fraction': 0.4837379651405908, 'bagging_freq': 2, 'min_child_samples': 9, 'max_depth': 668}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:43:31,333] Trial 475 finished with value: 0.8151678142119317 and parameters: {'lambda_l1': 2.0254012450378192e-08, 'lambda_l2': 5.976934163744881e-06, 'num_leaves': 244, 'feature_fraction': 0.5881140429200274, 'bagging_fraction': 0.49474165849253704, 'bagging_freq': 2, 'min_child_samples': 27, 'max_depth': 681}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:43:33,083] Trial 476 finished with value: 0.8470369862335807 and parameters: {'lambda_l1': 2.6085003950964045e-08, 'lambda_l2': 1.1674772220617189e-05, 'num_leaves': 248, 'feature_fraction': 0.5684599408448212, 'bagging_fraction': 0.46832384086236284, 'bagging_freq': 2, 'min_child_samples': 12, 'max_depth': 691}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:43:34,999] Trial 477 finished with value: 0.8351943489087451 and parameters: {'lambda_l1': 1.6648146798984803e-08, 'lambda_l2': 1.9538434592571716e-05, 'num_leaves': 232, 'feature_fraction': 0.6851756093490368, 'bagging_fraction': 0.5099519267157234, 'bagging_freq': 2, 'min_child_samples': 5, 'max_depth': 642}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:43:36,787] Trial 478 finished with value: 0.8555216641373762 and parameters: {'lambda_l1': 2.7891615631564172e-08, 'lambda_l2': 9.31631458512674e-06, 'num_leaves': 245, 'feature_fraction': 0.5846817310315757, 'bagging_fraction': 0.4809641391984535, 'bagging_freq': 2, 'min_child_samples': 8, 'max_depth': 662}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:43:38,891] Trial 479 finished with value: 0.8418516083160046 and parameters: {'lambda_l1': 5.533635476717455e-08, 'lambda_l2': 1.1860103341927426e-05, 'num_leaves': 251, 'feature_fraction': 0.5876613609814904, 'bagging_fraction': 0.5034318393329418, 'bagging_freq': 2, 'min_child_samples': 10, 'max_depth': 675}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:43:40,892] Trial 480 finished with value: 0.8478191721848841 and parameters: {'lambda_l1': 3.116458480989711e-08, 'lambda_l2': 2.2733253740226822e-05, 'num_leaves': 230, 'feature_fraction': 0.5898808730018338, 'bagging_fraction': 0.5145392849356467, 'bagging_freq': 2, 'min_child_samples': 13, 'max_depth': 655}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:43:42,926] Trial 481 finished with value: 0.8520437376520968 and parameters: {'lambda_l1': 3.154991053427259e-08, 'lambda_l2': 3.764113355327097e-05, 'num_leaves': 256, 'feature_fraction': 0.578177100235046, 'bagging_fraction': 0.4946905762167951, 'bagging_freq': 2, 'min_child_samples': 7, 'max_depth': 695}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:43:44,279] Trial 482 finished with value: 0.7079214032441585 and parameters: {'lambda_l1': 5.878268914710382, 'lambda_l2': 6.496284696310367e-06, 'num_leaves': 169, 'feature_fraction': 0.5921071399609676, 'bagging_fraction': 0.48493677357461334, 'bagging_freq': 2, 'min_child_samples': 11, 'max_depth': 673}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:43:45,059] Trial 483 finished with value: 0.5 and parameters: {'lambda_l1': 4.3725741086327716e-08, 'lambda_l2': 2.992540462289376e-05, 'num_leaves': 239, 'feature_fraction': 0.5737805579936904, 'bagging_fraction': 0.47870383221339585, 'bagging_freq': 2, 'min_child_samples': 94, 'max_depth': 623}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:43:47,015] Trial 484 finished with value: 0.8506211710546077 and parameters: {'lambda_l1': 2.4249112502967757e-08, 'lambda_l2': 5.686031916635281e-05, 'num_leaves': 221, 'feature_fraction': 0.5848899526864519, 'bagging_fraction': 0.47510280631261625, 'bagging_freq': 1, 'min_child_samples': 9, 'max_depth': 713}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:43:49,684] Trial 485 finished with value: 0.8479664631893735 and parameters: {'lambda_l1': 1.5246969765971342e-08, 'lambda_l2': 2.7704791351745134e-05, 'num_leaves': 214, 'feature_fraction': 0.6507595968695409, 'bagging_fraction': 0.4955040967890954, 'bagging_freq': 1, 'min_child_samples': 13, 'max_depth': 659}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:43:51,523] Trial 486 finished with value: 0.8405205535348724 and parameters: {'lambda_l1': 3.0635477870227964e-08, 'lambda_l2': 9.542133424064787e-06, 'num_leaves': 228, 'feature_fraction': 0.5711200632598814, 'bagging_fraction': 0.45978676903012267, 'bagging_freq': 2, 'min_child_samples': 7, 'max_depth': 700}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:43:53,325] Trial 487 finished with value: 0.8522896902289316 and parameters: {'lambda_l1': 6.483336953631985e-08, 'lambda_l2': 4.554291559656394e-05, 'num_leaves': 177, 'feature_fraction': 0.5979915716910422, 'bagging_fraction': 0.47253900995131837, 'bagging_freq': 1, 'min_child_samples': 11, 'max_depth': 683}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:43:55,221] Trial 488 finished with value: 0.8478082894917262 and parameters: {'lambda_l1': 2.109890155570553e-08, 'lambda_l2': 2.0347069954282056e-05, 'num_leaves': 123, 'feature_fraction': 0.5567724753214026, 'bagging_fraction': 0.5001442563885553, 'bagging_freq': 1, 'min_child_samples': 9, 'max_depth': 567}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:43:57,040] Trial 489 finished with value: 0.8297540875447221 and parameters: {'lambda_l1': 1.4013632151462182e-08, 'lambda_l2': 8.908593307944603e-05, 'num_leaves': 216, 'feature_fraction': 0.5818684977031847, 'bagging_fraction': 0.47214813894931384, 'bagging_freq': 1, 'min_child_samples': 5, 'max_depth': 707}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:43:58,761] Trial 490 finished with value: 0.8533151443499741 and parameters: {'lambda_l1': 1.006058442151682e-08, 'lambda_l2': 1.586841500483722e-05, 'num_leaves': 247, 'feature_fraction': 0.5949204724542383, 'bagging_fraction': 0.4612397100807138, 'bagging_freq': 4, 'min_child_samples': 13, 'max_depth': 668}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:44:00,830] Trial 491 finished with value: 0.842625641859001 and parameters: {'lambda_l1': 1.375009203460135e-07, 'lambda_l2': 4.823188021040734e-08, 'num_leaves': 236, 'feature_fraction': 0.5678043363899061, 'bagging_fraction': 0.48582425340187874, 'bagging_freq': 1, 'min_child_samples': 10, 'max_depth': 730}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:44:01,702] Trial 492 finished with value: 0.5 and parameters: {'lambda_l1': 3.913704721437233e-06, 'lambda_l2': 8.311365348398687e-06, 'num_leaves': 222, 'feature_fraction': 0.5810936880972313, 'bagging_fraction': 0.5284242360404835, 'bagging_freq': 1, 'min_child_samples': 53, 'max_depth': 695}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:44:03,680] Trial 493 finished with value: 0.8474343845868613 and parameters: {'lambda_l1': 3.9710589119637364e-08, 'lambda_l2': 4.530014248230157e-06, 'num_leaves': 217, 'feature_fraction': 0.6314217165729334, 'bagging_fraction': 0.4459578155247611, 'bagging_freq': 1, 'min_child_samples': 7, 'max_depth': 686}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:44:06,973] Trial 494 finished with value: 0.8551752050409172 and parameters: {'lambda_l1': 2.158497840565905e-08, 'lambda_l2': 7.551007973261925e-08, 'num_leaves': 244, 'feature_fraction': 0.6007716819738329, 'bagging_fraction': 0.43203795571121467, 'bagging_freq': 1, 'min_child_samples': 11, 'max_depth': 707}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:44:08,783] Trial 495 finished with value: 0.8493293739714018 and parameters: {'lambda_l1': 1.9488143809677598e-08, 'lambda_l2': 6.99629288449369e-08, 'num_leaves': 244, 'feature_fraction': 0.6130063208657858, 'bagging_fraction': 0.4360158588448294, 'bagging_freq': 2, 'min_child_samples': 15, 'max_depth': 659}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:44:10,826] Trial 496 finished with value: 0.8488962329809853 and parameters: {'lambda_l1': 2.6575094569282703e-08, 'lambda_l2': 7.612626025940575e-08, 'num_leaves': 238, 'feature_fraction': 0.6010050590042181, 'bagging_fraction': 0.4488767835018631, 'bagging_freq': 3, 'min_child_samples': 12, 'max_depth': 701}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:44:12,997] Trial 497 finished with value: 0.8393337193422333 and parameters: {'lambda_l1': 1.520711222330167e-08, 'lambda_l2': 1.2025547784650334e-07, 'num_leaves': 249, 'feature_fraction': 0.6236906757242304, 'bagging_fraction': 0.7751129231354286, 'bagging_freq': 1, 'min_child_samples': 14, 'max_depth': 715}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:44:14,932] Trial 498 finished with value: 0.8514585866919459 and parameters: {'lambda_l1': 2.434795574550691e-08, 'lambda_l2': 2.270231844373801e-08, 'num_leaves': 246, 'feature_fraction': 0.5552850493085791, 'bagging_fraction': 0.4648451734894832, 'bagging_freq': 1, 'min_child_samples': 11, 'max_depth': 649}. Best is trial 336 with value: 0.8591918981001799.
# [I 2022-06-21 22:44:16,859] Trial 499 finished with value: 0.852808302937173 and parameters: {'lambda_l1': 1.467054606115996e-08, 'lambda_l2': 4.078029760359868e-08, 'num_leaves': 232, 'feature_fraction': 0.59917375629782, 'bagging_fraction': 0.4327932875477452, 'bagging_freq': 1, 'min_child_samples': 13, 'max_depth': 682}. Best is trial 336 with value: 0.8591918981001799.

# %%
# Get best trial based on metric score
trial = study.best_trial
# Best Score from HP Opt
print(f'Best trial Score from HP Opt: {trial.values[0]:.4f}\n')

detailed_objective(trial)
# Out:
# Best trial Score from HP Opt: 0.8592
#
#     objective: binary
#     metric: binary_logloss
#     verbosity: -1
#     boosting_type: gbdt
#     lambda_l1: 2.146567505636963e-08
#     lambda_l2: 8.27476901340718e-07
#     num_leaves: 220
#     feature_fraction: 0.5865055793795527
#     bagging_fraction: 0.44814575746694135
#     bagging_freq: 1
#     min_child_samples: 9
#     n_estimators: 774
# [LightGBM] [Warning] feature_fraction is set=0.5865055793795527, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5865055793795527
# [LightGBM] [Warning] lambda_l1 is set=2.146567505636963e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.146567505636963e-08
# [LightGBM] [Warning] bagging_fraction is set=0.44814575746694135, subsample=1.0 will be ignored. Current value: bagging_fraction=0.44814575746694135
# [LightGBM] [Warning] lambda_l2 is set=8.27476901340718e-07, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.27476901340718e-07
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [TEST]
# balanced_accuracy: 0.7625, accuracy: 0.7969, specificity: 0.9000, sensitivity: 0.6250
# (0.7625, 0.796875, 0.9, 0.625)

# %% [markdown]
# ### Resultados
#
# | metrics                     	| normalizado 	| normalizado_v2 	| artigo 	| artigo_v2 	| artigo_v2 sem scaler  |
# |-----------------------------	|-------------	|----------------	|--------	|-----------    | --------------------  |
# | Best trial score (mean_val) 	| 89.86%      	| 81.03%         	| 84.22% 	| 85.98%    	| 85.92%                |
# | test balanced_accuracy      	| 52.71%      	| 63.33%         	| 57.58% 	| 72.08%    	| 76.25%                |
# | test accuracy               	| 57.81%      	| 68.75%         	| 65.62% 	| 76.56%    	| 79.68%                |
# | test specifity              	| 69.05%      	| 85.00%         	| 83.33% 	| 90.00%    	| 90.00%                |
# | test sensitivity            	| 36.36%      	| 41.67%         	| 31.82% 	| 54.15%    	| 62.50%                |
